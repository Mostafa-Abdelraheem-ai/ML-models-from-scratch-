# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from SVC import SoftMarginSVC,SoftMarginSVCPrimal,HardMarginSVC
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r"F:\mostafa\ML\course ML arabic Ahmed Rady\Day 37\nonlinear_data.csv")
data
# Out:
#      Feature 1  Feature 2  Label
# 0     3.764052   2.400157    0.0
# 1     2.978738   4.240893    0.0
# 2     3.867558   1.022722    0.0
# 3     2.950088   1.848643    0.0
# 4     1.896781   2.410599    0.0
# ..         ...        ...    ...
# 495   0.441033   0.178793    1.0
# 496  -0.799422   0.240788    1.0
# 497   0.289121   0.412871    1.0
# 498  -0.198399   0.094192    1.0
# 499  -1.147611  -0.358114    1.0
#
# [500 rows x 3 columns]

# %%
x = data.drop(["Label"],axis=1)
y = data["Label"] 
y = np.where(y==0,-1,1)

# %%
scaler = StandardScaler()
X_Std = scaler.fit_transform(x)

# %%
model = HardMarginSVC()
model.fit(X_Std,y)
plt.scatter(X_Std[:,0],X_Std[:,1],c = y)
xx1, xx2 = np.meshgrid(
    np.arange(-2,2,.01),
    np.arange(-2,2,.01)
)
meshgred_points = np.array([xx1.ravel(),xx2.ravel()]).T
z = model.predict(meshgred_points)
z = z.reshape(xx1.shape)
plt.contourf(xx1, xx2, z,alpha = .2)
print(model.score(X_Std,y))
plt.contourf(xx1,xx2,z,alpha=0.2)
# Out:
# 0.894
