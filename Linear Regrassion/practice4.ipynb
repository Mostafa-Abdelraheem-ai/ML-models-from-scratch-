# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
path = r"G:\course ML arabic Ahmed Rady\Day 11\task.csv"
data=pd.read_csv(path)
data.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5/2/2014 0:00   313000.0       3.0       1.50       1340.0    7912.0
# 1  5/2/2014 0:00  2384000.0       5.0       2.50       3650.0    9050.0
# 2  5/2/2014 0:00   342000.0       3.0       2.00       1930.0   11947.0
# 3  5/2/2014 0:00   420000.0       3.0       2.25       2000.0    8030.0
# 4  5/2/2014 0:00   550000.0       4.0       2.50       1940.0   10500.0
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5         0.0   0.0        3.0      1340.0            0.0    1955.0
# 1     2.0         0.0   4.0        5.0      3370.0          280.0    1921.0
# 2     1.0         0.0   0.0        4.0      1930.0            0.0    1966.0
# 3     1.0         0.0   0.0        4.0      1000.0         1000.0    1963.0
# 4     1.0         0.0   0.0        4.0      1140.0          800.0    1976.0
#
#    yr_renovated                    street       city  statezip country
# ...

# %%
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4463 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4463 non-null   object
#  1   price          4463 non-null   float64
#  2   bedrooms       4463 non-null   float64
#  3   bathrooms      4463 non-null   float64
#  4   sqft_living    4463 non-null   float64
#  5   sqft_lot       4463 non-null   float64
#  6   floors         4463 non-null   float64
#  7   waterfront     4463 non-null   float64
#  8   view           4463 non-null   float64
#  9   condition      4463 non-null   float64
#  10  sqft_above     4463 non-null   float64
#  11  sqft_basement  4463 non-null   float64
#  12  yr_built       4463 non-null   float64
#  13  yr_renovated   4463 non-null   float64
#  14  street         4463 non-null   object
#  15  city           4463 non-null   object
#  16  statezip       4463 non-null   object
# ...

# %%
x = data.drop(["date","price","street","city","statezip","country"],axis=1)
y = data["price"]

myModel = LinearRegression()
myModel.fit(x,y)
myModel.score(x,y)
# Out:
# 0.21476654846723686

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.463000e+03  4463.000000  4463.000000   4463.000000  4.463000e+03
# mean   5.522506e+05     3.403316     2.161943   2140.622003  1.493180e+04
# std    5.698129e+05     0.911114     0.786807    965.843314  3.619894e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.219750e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.600000e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549750e+05     4.000000     2.500000   2620.000000  1.100000e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4463.000000  4463.000000  4463.000000  4463.000000  4463.000000
# mean      1.512996     0.007394     0.241093     3.453058  1828.875420
# std       0.536800     0.085680     0.781708     0.678464   865.210364
# ...

# %%
data[data==0].count()
# Out:
# date                0
# price              49
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4430
# view             4019
# condition           0
# sqft_above          0
# sqft_basement    2665
# yr_built            0
# yr_renovated     2656
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
data["view"].unique()
# Out:
# array([0., 4., 1., 2., 3.])

# %%
data = data[data["price"]!=0]

# %%
data[data==0].count()
# Out:
# date                0
# price               0
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4384
# view             3982
# condition           0
# sqft_above          0
# sqft_basement    2638
# yr_built            0
# yr_renovated     2627
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
data = data[data["bathrooms"] != 0]
data = data[data["bedrooms"] != 0]

# %%
data[data==0].count()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4382
# view             3981
# condition           0
# sqft_above          0
# sqft_basement    2636
# yr_built            0
# yr_renovated     2627
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
data.corr()
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_9924\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.208860   0.340622     0.441737  0.050072  0.152008
# bedrooms       0.208860  1.000000   0.545416     0.600566  0.068644  0.183007
# bathrooms      0.340622  0.545416   1.000000     0.762477  0.108283  0.494397
# sqft_living    0.441737  0.600566   0.762477     1.000000  0.210334  0.346930
# sqft_lot       0.050072  0.068644   0.108283     0.210334  1.000000  0.004685
# floors         0.152008  0.183007   0.494397     0.346930  0.004685  1.000000
# waterfront     0.150811 -0.005961   0.063961     0.109234  0.017342  0.016061
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_9924\460133985.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
plt.figure(figsize=(15,6))
sns.histplot(data["price"],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
data = data[data["price"]<.6e07]

# %%
sns.histplot(data["price"],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=((15,6)))
plt.scatter(data["sqft_living"],data["price"])

# %%
data["sqft_living"] = np.where(data["sqft_living"]>6000,6000,data["sqft_living"])

# %%
plt.figure(figsize=((15,6)))
plt.scatter(data["sqft_living"],data["price"])

# %%
plt.figure(figsize=((15,6)))
plt.scatter(data["sqft_basement"],data["price"])

# %%
data["sqft_basement"] = np.where(data["sqft_basement"]>2000,2000,data["sqft_basement"])

# %%
plt.figure(figsize=(15,6))
plt.scatter(data["sqft_basement"],data["price"])

# %%
plt.figure(figsize=(15,6))
plt.scatter(data["sqft_above"],data["price"])

# %%
data["sqft_above"] = np.where(data["sqft_above"]>5000,5000,data["sqft_above"])

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x=data["sqft_above"],y=data["price"])
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=data["bedrooms"],y=data["price"])
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
x = data.drop(["date","price","street","city","statezip","country"],axis=1)
y = data["price"]
myModel.fit(x,y)
myModel.score(x,y)
# Out:
# 0.5649327462269818

# %%
data
# Out:
#                 date         price  bedrooms  bathrooms  sqft_living  \
# 0      5/2/2014 0:00  3.130000e+05       3.0       1.50       1340.0
# 1      5/2/2014 0:00  2.384000e+06       5.0       2.50       3650.0
# 2      5/2/2014 0:00  3.420000e+05       3.0       2.00       1930.0
# 3      5/2/2014 0:00  4.200000e+05       3.0       2.25       2000.0
# 4      5/2/2014 0:00  5.500000e+05       4.0       2.50       1940.0
# ...              ...           ...       ...        ...          ...
# 4595   7/9/2014 0:00  3.081667e+05       3.0       1.75       1510.0
# 4596   7/9/2014 0:00  5.343333e+05       3.0       2.50       1460.0
# 4597   7/9/2014 0:00  4.169042e+05       3.0       2.50       3010.0
# 4598  7/10/2014 0:00  2.034000e+05       4.0       2.00       2090.0
# 4599  7/10/2014 0:00  2.206000e+05       3.0       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0       7912.0     1.5         0.0   0.0        3.0      1340.0
# ...

# %%
data[data==0].count()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4380
# view             3979
# condition           0
# sqft_above          0
# sqft_basement    2635
# yr_built            0
# yr_renovated     2626
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms  sqft_living      sqft_lot  \
# count  4.409000e+03  4409.000000  4409.000000  4409.000000  4.409000e+03
# mean   5.479138e+05     3.398276     2.156385  2125.861193  1.491157e+04
# std    3.564571e+05     0.904043     0.777483   918.689630  3.630179e+04
# min    7.800000e+03     1.000000     0.750000   370.000000  6.380000e+02
# 25%    3.259000e+05     3.000000     1.750000  1460.000000  5.000000e+03
# 50%    4.650000e+05     3.000000     2.250000  1970.000000  7.680000e+03
# 75%    6.570000e+05     4.000000     2.500000  2610.000000  1.092000e+04
# max    4.668000e+06     9.000000     8.000000  6000.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4409.000000  4409.000000  4409.000000  4409.000000  4409.000000
# mean      1.512701     0.006577     0.234293     3.450896  1817.914039
# std       0.536294     0.080844     0.767857     0.676548   833.013677
# ...

# %%
data.corr()
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_9924\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.337617   0.532761     0.683325  0.081545  0.262785
# bedrooms       0.337617  1.000000   0.545024     0.608294  0.068398  0.182579
# bathrooms      0.532761  0.545024   1.000000     0.759670  0.107981  0.494499
# sqft_living    0.683325  0.608294   0.759670     1.000000  0.197426  0.352970
# sqft_lot       0.081545  0.068398   0.107981     0.197426  1.000000  0.004496
# floors         0.262785  0.182579   0.494499     0.352970  0.004496  1.000000
# waterfront     0.196428 -0.011019   0.056719     0.081171  0.015911  0.013770
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_9924\460133985.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
data["bedrooms"].value_counts().sort_index()
# Out:
# 1.0      37
# 2.0     540
# 3.0    1961
# 4.0    1469
# 5.0     326
# 6.0      59
# 7.0      14
# 8.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
data["bedrooms"] = np.where(data["bedrooms"]>6,6,data["bedrooms"])

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=data["bedrooms"],y=data["price"])
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=data["bathrooms"],y=data["price"])
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
data["bathrooms"].value_counts().sort_index()
# Out:
# 0.75      17
# 1.00     714
# 1.25       3
# 1.50     281
# 1.75     606
# 2.00     413
# 2.25     400
# 2.50    1139
# 2.75     267
# 3.00     158
# 3.25     128
# 3.50     157
# 3.75      34
# 4.00      21
# 4.25      21
# 4.50      25
# 4.75       7
# 5.00       5
# 5.25       4
# 5.50       4
# 5.75       1
# 6.25       1
# 6.50       1
# 6.75       1
# 8.00       1
# Name: bathrooms, dtype: int64

# %%
data["bathrooms"] = np.where(data["bathrooms"]==0.75,1,data["bathrooms"])
data["bathrooms"] = np.where(data["bathrooms"]==1.25,1,data["bathrooms"])

data["bathrooms"] = np.where(data["bathrooms"]>4.50,4.50,data["bathrooms"])

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=data["bathrooms"],y=data["price"])
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_9924\460133985.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4409 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4409 non-null   object
#  1   price          4409 non-null   float64
#  2   bedrooms       4409 non-null   float64
#  3   bathrooms      4409 non-null   float64
#  4   sqft_living    4409 non-null   float64
#  5   sqft_lot       4409 non-null   float64
#  6   floors         4409 non-null   float64
#  7   waterfront     4409 non-null   float64
#  8   view           4409 non-null   float64
#  9   condition      4409 non-null   float64
#  10  sqft_above     4409 non-null   float64
#  11  sqft_basement  4409 non-null   float64
#  12  yr_built       4409 non-null   float64
#  13  yr_renovated   4409 non-null   float64
#  14  street         4409 non-null   object
#  15  city           4409 non-null   object
#  16  statezip       4409 non-null   object
# ...

# %%
data = data.drop(["date","sqft_lot","yr_built","yr_renovated","condition","sqft_above","city","country","street"],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4409 entries, 0 to 4599
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4409 non-null   float64
#  1   bedrooms       4409 non-null   float64
#  2   bathrooms      4409 non-null   float64
#  3   sqft_living    4409 non-null   float64
#  4   floors         4409 non-null   float64
#  5   waterfront     4409 non-null   float64
#  6   view           4409 non-null   float64
#  7   sqft_basement  4409 non-null   float64
#  8   statezip       4409 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 344.5+ KB

# %%
data = pd.get_dummies(data,columns=["statezip"])

# %%
data
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0     3.130000e+05       3.0       1.50       1340.0     1.5         0.0
# 1     2.384000e+06       5.0       2.50       3650.0     2.0         0.0
# 2     3.420000e+05       3.0       2.00       1930.0     1.0         0.0
# 3     4.200000e+05       3.0       2.25       2000.0     1.0         0.0
# 4     5.500000e+05       4.0       2.50       1940.0     1.0         0.0
# ...            ...       ...        ...          ...     ...         ...
# 4595  3.081667e+05       3.0       1.75       1510.0     1.0         0.0
# 4596  5.343333e+05       3.0       2.50       1460.0     2.0         0.0
# 4597  4.169042e+05       3.0       2.50       3010.0     2.0         0.0
# 4598  2.034000e+05       4.0       2.00       2090.0     1.0         0.0
# 4599  2.206000e+05       3.0       2.50       1490.0     2.0         0.0
#
#       view  sqft_basement  statezip_WA 98001  statezip_WA 98002  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4409 entries, 0 to 4599
# Data columns (total 85 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              4409 non-null   float64
#  1   bedrooms           4409 non-null   float64
#  2   bathrooms          4409 non-null   float64
#  3   sqft_living        4409 non-null   float64
#  4   floors             4409 non-null   float64
#  5   waterfront         4409 non-null   float64
#  6   view               4409 non-null   float64
#  7   sqft_basement      4409 non-null   float64
#  8   statezip_WA 98001  4409 non-null   uint8
#  9   statezip_WA 98002  4409 non-null   uint8
#  10  statezip_WA 98003  4409 non-null   uint8
#  11  statezip_WA 98004  4409 non-null   uint8
#  12  statezip_WA 98005  4409 non-null   uint8
#  13  statezip_WA 98006  4409 non-null   uint8
#  14  statezip_WA 98007  4409 non-null   uint8
#  15  statezip_WA 98008  4409 non-null   uint8
# ...

# %%
x = data.drop(["price"],axis=1)
y = data["price"]

myModel.fit(x,y)
myModel.score(x,y)
# Out:
# 0.7603390138983883
