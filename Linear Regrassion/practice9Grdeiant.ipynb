# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %%
x = np.random.randn(100).reshape(-1,1)
y = 5*x + 7 + 2*np.random.randn(100).reshape(-1,1)

# %%
plt.scatter(x,y)

# %%
model = LinearRegression()
model.fit(x,y)
model.score(x,y)
# Out:
# 0.8807956372664144

# %%
second_model =  SGDRegressor(max_iter=1000,tol=1e-10)
second_model.fit(x,y)
second_model.score(x,y)
# Out:
# c:\Users\Toshiba\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8807948744251247
